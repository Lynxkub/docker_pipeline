# %%
import pandas as pd





meta_load_dt = '2024-07-19-18-08-52'
prev_meta_load_dt = '2024-07-19-17-05-07'




df_raw = pd.read_csv('home_data_2.csv')
df_curated_previous = pd.read_csv('curated_home_data.csv')


print(df_raw.count())
print(df_curated_previous.count())
# Out:
# Unnamed: 0            495
# city                  495
# price                 495
# beds                  495
# baths                 495
# sqft                  495
# url                   495
# address               495
# ins_dttm              495
# extract_dttm          495
# delete_dttm             0
# orig_listing_price    495
# list_price_change       0
# dtype: int64
# Unnamed: 0.1    490
# Unnamed: 0      490
# city            490
# price           490
# beds            490
# baths           490
# sqft            490
# url             490
# address         490
# active_flag     490
# delete_flag     490
# meta_load_dt    490
# dtype: int64

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# aiobotocore               2.13.1
# aiohttp                   3.9.5
# aioitertools              0.11.0
# aiosignal                 1.3.1
# anyio                     4.4.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.15.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# boto3                     1.34.145
# botocore                  1.34.131
# certifi                   2024.6.2
# cffi                      1.16.0
# charset-normalizer        3.3.2
# colorama                  0.4.6
# comm                      0.2.2
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# distlib                   0.3.8
# executing                 2.0.1
# ...
